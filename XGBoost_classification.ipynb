# %% [markdown]
# # Part 1 of 3: Get key packages and data

# %%
#-- get key packages

import io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, classification_report, roc_auc_score
from sklearn.model_selection import train_test_split, GridSearchCV

#-- make sure we can read in the file without having to scan for viruses

# !pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
from google.colab import auth
from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseDownload

auth.authenticate_user()

def download_file_from_google_drive(file_id):
    drive_service = build('drive', 'v3')
    request = drive_service.files().get_media(fileId=file_id)
    downloaded = io.BytesIO()
    downloader = MediaIoBaseDownload(downloaded, request)
    done = False
    while done is False:
        status, done = downloader.next_chunk()
        print("Download %d%%." % int(status.progress() * 100))
    downloaded.seek(0)
    return downloaded

#-- get data

file_id_training = '1j1bCvwfs4RUU-IocMr6qwAiyvBC-YURd'
file_id_test = '1C9Y8ppzcqm3ZcZ1eGa4w7NurdV-EJh4D'

training_data = download_file_from_google_drive(file_id_training)
test_data = download_file_from_google_drive(file_id_test)

df_training = pd.read_csv(training_data)
df_test = pd.read_csv(test_data)

print('### Viewing the head of training and testing data')
print(df_training.head())
print('')
print(df_test.head())
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (2.84.0)
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.125.0-py2.py3-none-any.whl (12.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 56.8 MB/s eta 0:00:00
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.10/dist-packages (0.1.1)
# Collecting google-auth-httplib2
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.10/dist-packages (1.2.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (2.27.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.1.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2024.2.2)
# Installing collected packages: google-auth-httplib2, google-api-python-client
#   Attempting uninstall: google-auth-httplib2
#     Found existing installation: google-auth-httplib2 0.1.1
#     Uninstalling google-auth-httplib2-0.1.1:
#       Successfully uninstalled google-auth-httplib2-0.1.1
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.84.0
#     Uninstalling google-api-python-client-2.84.0:
#       Successfully uninstalled google-api-python-client-2.84.0
# Successfully installed google-api-python-client-2.125.0 google-auth-httplib2-0.2.0
# Download 34%.
# Download 69%.
# Download 100%.
# Download 34%.
# Download 69%.
# Download 100%.
# ### Viewing the head of training and testing data
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250  ...   4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# 0   7.8784   8.5635  12.7803  -1.0914
# 1   8.1267   8.7889  18.3560   1.9518
# 2  -6.5213   8.2675  14.7222   0.3965
# 3  -2.9275  10.2922  17.9697  -8.9996
# 4   3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 202 columns]
#
#   ID_code    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  test_0  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 1  test_1   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 2  test_2   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 3  test_3   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 4  test_4  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#      var_7   var_8  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.2675  2.1337  ...  -2.1556  11.8495  -1.4300   2.4508  13.7112   2.4669
# 1  18.6316 -4.4131  ...  10.6165   8.8349   0.9403  10.1282  15.5765   0.4773
# 2  20.2537  1.5233  ...  -0.7484  10.9935   1.9803   2.1800  12.9813   2.1281
# 3  20.5660  3.3755  ...   9.5702   9.0766   1.6580   3.5813  15.1874   3.1656
# 4  10.6048  2.9890  ...   4.2259   9.1723   1.2835   3.3778  19.5542  -0.2860
#
#    var_196  var_197  var_198  var_199
# 0   4.3654  10.7200  15.4722  -8.7197
# 1  -1.4852   9.8714  19.1293 -20.9760
# 2  -7.1086   7.0618  19.8956 -23.1794
# 3   3.9567   9.2295  13.0168  -4.2108
# 4  -5.1612   7.2882  13.9260  -9.1846
#
# [5 rows x 201 columns]

# %% [markdown]
# # Part 2 of 3: Try a model

# %%
#-- split data into training and testing portions

var_cols = [x for x in df_training.columns if x not in ['ID_code', 'target']]
X = df_training.loc[:, var_cols]
y = df_training.loc[:, 'target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

test_set = [(X_test, y_test)]

# %%
print(df_training['target'].unique())
# Out:
# [0 1]

# %%
#-- view default parameters

dict_DefaultParams = xgboost.XGBClassifier().get_params()
print(dict_DefaultParams)
# Out:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': None, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': None, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}

# %%
#-- try a model

model_xgboost = xgboost.XGBClassifier(learning_rate=0.1,
                                      max_depth=5,
                                      n_estimators=5000,
                                      subsample=0.5,
                                      colsample_bytree=0.5,
                                      eval_metric='auc',
                                      verbosity=1)

model_xgboost.fit(X_train,
                  y_train,
                  early_stopping_rounds=10,
                  eval_set=test_set,
                  verbose=True)

y_preds_train = model_xgboost.predict_proba(X_train)[:, 1]
y_preds_test = model_xgboost.predict_proba(X_test)[:, 1]

auc_train = roc_auc_score(y_train, y_preds_train)
auc_test = roc_auc_score(y_test, y_preds_test)

print('### performance metrics for the model')
print(f'# auc_train: {auc_train:.3f}')
print(f'# auc_test: {auc_test:.3f}')
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-auc:0.63056
# [1]	validation_0-auc:0.66356
# [2]	validation_0-auc:0.67492
# [3]	validation_0-auc:0.68708
# [4]	validation_0-auc:0.69386
# [5]	validation_0-auc:0.70100
# [6]	validation_0-auc:0.71445
# [7]	validation_0-auc:0.72434
# [8]	validation_0-auc:0.73182
# [9]	validation_0-auc:0.73992
# [10]	validation_0-auc:0.74229
# [11]	validation_0-auc:0.74606
# [12]	validation_0-auc:0.74978
# [13]	validation_0-auc:0.75133
# [14]	validation_0-auc:0.75790
# [15]	validation_0-auc:0.76117
# [16]	validation_0-auc:0.76515
# [17]	validation_0-auc:0.76988
# [18]	validation_0-auc:0.77291
# [19]	validation_0-auc:0.77502
# [20]	validation_0-auc:0.77609
# [21]	validation_0-auc:0.77929
# [22]	validation_0-auc:0.78212
# [23]	validation_0-auc:0.78383
# [24]	validation_0-auc:0.78690
# [25]	validation_0-auc:0.79035
# [26]	validation_0-auc:0.79246
# [27]	validation_0-auc:0.79489
# [28]	validation_0-auc:0.79577
# [29]	validation_0-auc:0.79776
# [30]	validation_0-auc:0.79890
# [31]	validation_0-auc:0.80101
# [32]	validation_0-auc:0.80358
# [33]	validation_0-auc:0.80517
# [34]	validation_0-auc:0.80642
# [35]	validation_0-auc:0.80734
# [36]	validation_0-auc:0.80929
# [37]	validation_0-auc:0.81100
# [38]	validation_0-auc:0.81218
# [39]	validation_0-auc:0.81370
# [40]	validation_0-auc:0.81433
# [41]	validation_0-auc:0.81623
# [42]	validation_0-auc:0.81794
# [43]	validation_0-auc:0.81953
# [44]	validation_0-auc:0.81974
# [45]	validation_0-auc:0.82066
# [46]	validation_0-auc:0.82188
# [47]	validation_0-auc:0.82272
# [48]	validation_0-auc:0.82310
# [49]	validation_0-auc:0.82484
# [50]	validation_0-auc:0.82552
# [51]	validation_0-auc:0.82653
# [52]	validation_0-auc:0.82765
# [53]	validation_0-auc:0.82827
# [54]	validation_0-auc:0.82901
# [55]	validation_0-auc:0.83028
# [56]	validation_0-auc:0.83183
# [57]	validation_0-auc:0.83253
# [58]	validation_0-auc:0.83333
# [59]	validation_0-auc:0.83398
# [60]	validation_0-auc:0.83432
# [61]	validation_0-auc:0.83531
# [62]	validation_0-auc:0.83594
# [63]	validation_0-auc:0.83651
# [64]	validation_0-auc:0.83730
# [65]	validation_0-auc:0.83842
# [66]	validation_0-auc:0.83897
# [67]	validation_0-auc:0.83905
# [68]	validation_0-auc:0.84010
# [69]	validation_0-auc:0.84106
# [70]	validation_0-auc:0.84194
# [71]	validation_0-auc:0.84323
# [72]	validation_0-auc:0.84379
# [73]	validation_0-auc:0.84459
# [74]	validation_0-auc:0.84528
# [75]	validation_0-auc:0.84588
# [76]	validation_0-auc:0.84637
# [77]	validation_0-auc:0.84715
# [78]	validation_0-auc:0.84771
# [79]	validation_0-auc:0.84787
# [80]	validation_0-auc:0.84876
# [81]	validation_0-auc:0.84933
# [82]	validation_0-auc:0.84984
# [83]	validation_0-auc:0.85006
# [84]	validation_0-auc:0.85053
# [85]	validation_0-auc:0.85105
# [86]	validation_0-auc:0.85183
# [87]	validation_0-auc:0.85250
# [88]	validation_0-auc:0.85269
# [89]	validation_0-auc:0.85315
# [90]	validation_0-auc:0.85332
# [91]	validation_0-auc:0.85371
# [92]	validation_0-auc:0.85407
# [93]	validation_0-auc:0.85453
# [94]	validation_0-auc:0.85477
# [95]	validation_0-auc:0.85529
# [96]	validation_0-auc:0.85586
# [97]	validation_0-auc:0.85621
# [98]	validation_0-auc:0.85691
# [99]	validation_0-auc:0.85726
# [100]	validation_0-auc:0.85766
# [101]	validation_0-auc:0.85806
# [102]	validation_0-auc:0.85844
# [103]	validation_0-auc:0.85871
# [104]	validation_0-auc:0.85911
# [105]	validation_0-auc:0.85936
# [106]	validation_0-auc:0.85990
# [107]	validation_0-auc:0.86031
# [108]	validation_0-auc:0.86074
# [109]	validation_0-auc:0.86084
# [110]	validation_0-auc:0.86106
# [111]	validation_0-auc:0.86137
# [112]	validation_0-auc:0.86158
# [113]	validation_0-auc:0.86189
# [114]	validation_0-auc:0.86184
# [115]	validation_0-auc:0.86211
# [116]	validation_0-auc:0.86240
# [117]	validation_0-auc:0.86252
# [118]	validation_0-auc:0.86301
# [119]	validation_0-auc:0.86306
# [120]	validation_0-auc:0.86333
# [121]	validation_0-auc:0.86359
# [122]	validation_0-auc:0.86375
# [123]	validation_0-auc:0.86392
# [124]	validation_0-auc:0.86435
# [125]	validation_0-auc:0.86472
# [126]	validation_0-auc:0.86504
# [127]	validation_0-auc:0.86530
# [128]	validation_0-auc:0.86549
# [129]	validation_0-auc:0.86558
# [130]	validation_0-auc:0.86575
# [131]	validation_0-auc:0.86615
# [132]	validation_0-auc:0.86623
# [133]	validation_0-auc:0.86644
# [134]	validation_0-auc:0.86669
# [135]	validation_0-auc:0.86690
# [136]	validation_0-auc:0.86717
# [137]	validation_0-auc:0.86740
# [138]	validation_0-auc:0.86758
# [139]	validation_0-auc:0.86779
# [140]	validation_0-auc:0.86774
# [141]	validation_0-auc:0.86785
# [142]	validation_0-auc:0.86816
# [143]	validation_0-auc:0.86841
# [144]	validation_0-auc:0.86891
# [145]	validation_0-auc:0.86902
# [146]	validation_0-auc:0.86930
# [147]	validation_0-auc:0.86947
# [148]	validation_0-auc:0.86961
# [149]	validation_0-auc:0.86986
# [150]	validation_0-auc:0.87001
# [151]	validation_0-auc:0.87027
# [152]	validation_0-auc:0.87052
# [153]	validation_0-auc:0.87071
# [154]	validation_0-auc:0.87072
# [155]	validation_0-auc:0.87094
# [156]	validation_0-auc:0.87118
# [157]	validation_0-auc:0.87139
# [158]	validation_0-auc:0.87162
# [159]	validation_0-auc:0.87180
# [160]	validation_0-auc:0.87186
# [161]	validation_0-auc:0.87204
# [162]	validation_0-auc:0.87224
# [163]	validation_0-auc:0.87249
# [164]	validation_0-auc:0.87277
# [165]	validation_0-auc:0.87312
# [166]	validation_0-auc:0.87335
# [167]	validation_0-auc:0.87361
# [168]	validation_0-auc:0.87385
# [169]	validation_0-auc:0.87418
# [170]	validation_0-auc:0.87432
# [171]	validation_0-auc:0.87452
# [172]	validation_0-auc:0.87452
# [173]	validation_0-auc:0.87471
# [174]	validation_0-auc:0.87478
# [175]	validation_0-auc:0.87497
# [176]	validation_0-auc:0.87518
# [177]	validation_0-auc:0.87535
# [178]	validation_0-auc:0.87556
# [179]	validation_0-auc:0.87567
# [180]	validation_0-auc:0.87584
# [181]	validation_0-auc:0.87608
# [182]	validation_0-auc:0.87628
# [183]	validation_0-auc:0.87631
# [184]	validation_0-auc:0.87654
# [185]	validation_0-auc:0.87664
# [186]	validation_0-auc:0.87685
# [187]	validation_0-auc:0.87714
# [188]	validation_0-auc:0.87725
# [189]	validation_0-auc:0.87738
# [190]	validation_0-auc:0.87739
# [191]	validation_0-auc:0.87739
# [192]	validation_0-auc:0.87761
# [193]	validation_0-auc:0.87788
# [194]	validation_0-auc:0.87798
# [195]	validation_0-auc:0.87814
# [196]	validation_0-auc:0.87824
# [197]	validation_0-auc:0.87824
# [198]	validation_0-auc:0.87842
# [199]	validation_0-auc:0.87866
# [200]	validation_0-auc:0.87881
# [201]	validation_0-auc:0.87893
# [202]	validation_0-auc:0.87912
# [203]	validation_0-auc:0.87928
# [204]	validation_0-auc:0.87942
# [205]	validation_0-auc:0.87953
# [206]	validation_0-auc:0.87969
# [207]	validation_0-auc:0.87981
# [208]	validation_0-auc:0.87978
# [209]	validation_0-auc:0.87992
# [210]	validation_0-auc:0.87997
# [211]	validation_0-auc:0.88009
# [212]	validation_0-auc:0.88011
# [213]	validation_0-auc:0.88024
# [214]	validation_0-auc:0.88035
# [215]	validation_0-auc:0.88049
# [216]	validation_0-auc:0.88064
# [217]	validation_0-auc:0.88079
# [218]	validation_0-auc:0.88075
# [219]	validation_0-auc:0.88074
# [220]	validation_0-auc:0.88087
# [221]	validation_0-auc:0.88091
# [222]	validation_0-auc:0.88101
# [223]	validation_0-auc:0.88112
# [224]	validation_0-auc:0.88120
# [225]	validation_0-auc:0.88127
# [226]	validation_0-auc:0.88145
# [227]	validation_0-auc:0.88157
# [228]	validation_0-auc:0.88164
# [229]	validation_0-auc:0.88180
# [230]	validation_0-auc:0.88180
# [231]	validation_0-auc:0.88189
# [232]	validation_0-auc:0.88202
# [233]	validation_0-auc:0.88200
# [234]	validation_0-auc:0.88209
# [235]	validation_0-auc:0.88221
# [236]	validation_0-auc:0.88214
# [237]	validation_0-auc:0.88218
# [238]	validation_0-auc:0.88220
# [239]	validation_0-auc:0.88230
# [240]	validation_0-auc:0.88255
# [241]	validation_0-auc:0.88265
# [242]	validation_0-auc:0.88268
# [243]	validation_0-auc:0.88266
# [244]	validation_0-auc:0.88269
# [245]	validation_0-auc:0.88283
# [246]	validation_0-auc:0.88290
# [247]	validation_0-auc:0.88297
# [248]	validation_0-auc:0.88310
# [249]	validation_0-auc:0.88320
# [250]	validation_0-auc:0.88327
# [251]	validation_0-auc:0.88330
# [252]	validation_0-auc:0.88330
# [253]	validation_0-auc:0.88339
# [254]	validation_0-auc:0.88346
# [255]	validation_0-auc:0.88350
# [256]	validation_0-auc:0.88359
# [257]	validation_0-auc:0.88378
# [258]	validation_0-auc:0.88383
# [259]	validation_0-auc:0.88379
# [260]	validation_0-auc:0.88393
# [261]	validation_0-auc:0.88390
# [262]	validation_0-auc:0.88409
# [263]	validation_0-auc:0.88420
# [264]	validation_0-auc:0.88431
# [265]	validation_0-auc:0.88439
# [266]	validation_0-auc:0.88444
# [267]	validation_0-auc:0.88458
# [268]	validation_0-auc:0.88452
# [269]	validation_0-auc:0.88461
# [270]	validation_0-auc:0.88472
# [271]	validation_0-auc:0.88490
# [272]	validation_0-auc:0.88498
# [273]	validation_0-auc:0.88503
# [274]	validation_0-auc:0.88510
# [275]	validation_0-auc:0.88519
# [276]	validation_0-auc:0.88514
# [277]	validation_0-auc:0.88515
# [278]	validation_0-auc:0.88521
# [279]	validation_0-auc:0.88522
# [280]	validation_0-auc:0.88528
# [281]	validation_0-auc:0.88528
# [282]	validation_0-auc:0.88535
# [283]	validation_0-auc:0.88535
# [284]	validation_0-auc:0.88539
# [285]	validation_0-auc:0.88541
# [286]	validation_0-auc:0.88549
# [287]	validation_0-auc:0.88549
# [288]	validation_0-auc:0.88551
# [289]	validation_0-auc:0.88564
# [290]	validation_0-auc:0.88568
# [291]	validation_0-auc:0.88577
# [292]	validation_0-auc:0.88577
# [293]	validation_0-auc:0.88573
# [294]	validation_0-auc:0.88579
# [295]	validation_0-auc:0.88585
# [296]	validation_0-auc:0.88596
# [297]	validation_0-auc:0.88595
# [298]	validation_0-auc:0.88605
# [299]	validation_0-auc:0.88606
# [300]	validation_0-auc:0.88606
# [301]	validation_0-auc:0.88621
# [302]	validation_0-auc:0.88619
# [303]	validation_0-auc:0.88620
# [304]	validation_0-auc:0.88626
# [305]	validation_0-auc:0.88635
# [306]	validation_0-auc:0.88646
# [307]	validation_0-auc:0.88643
# [308]	validation_0-auc:0.88641
# [309]	validation_0-auc:0.88643
# [310]	validation_0-auc:0.88640
# [311]	validation_0-auc:0.88654
# [312]	validation_0-auc:0.88658
# [313]	validation_0-auc:0.88668
# [314]	validation_0-auc:0.88678
# [315]	validation_0-auc:0.88684
# [316]	validation_0-auc:0.88680
# [317]	validation_0-auc:0.88689
# [318]	validation_0-auc:0.88698
# [319]	validation_0-auc:0.88706
# [320]	validation_0-auc:0.88709
# [321]	validation_0-auc:0.88709
# [322]	validation_0-auc:0.88713
# [323]	validation_0-auc:0.88712
# [324]	validation_0-auc:0.88710
# [325]	validation_0-auc:0.88711
# [326]	validation_0-auc:0.88715
# [327]	validation_0-auc:0.88724
# [328]	validation_0-auc:0.88729
# [329]	validation_0-auc:0.88733
# [330]	validation_0-auc:0.88743
# [331]	validation_0-auc:0.88754
# [332]	validation_0-auc:0.88752
# [333]	validation_0-auc:0.88755
# [334]	validation_0-auc:0.88756
# [335]	validation_0-auc:0.88760
# [336]	validation_0-auc:0.88767
# [337]	validation_0-auc:0.88775
# [338]	validation_0-auc:0.88783
# [339]	validation_0-auc:0.88784
# [340]	validation_0-auc:0.88786
# [341]	validation_0-auc:0.88796
# [342]	validation_0-auc:0.88797
# [343]	validation_0-auc:0.88804
# [344]	validation_0-auc:0.88806
# [345]	validation_0-auc:0.88811
# [346]	validation_0-auc:0.88819
# [347]	validation_0-auc:0.88822
# [348]	validation_0-auc:0.88830
# [349]	validation_0-auc:0.88826
# [350]	validation_0-auc:0.88829
# [351]	validation_0-auc:0.88832
# [352]	validation_0-auc:0.88837
# [353]	validation_0-auc:0.88831
# [354]	validation_0-auc:0.88843
# [355]	validation_0-auc:0.88851
# [356]	validation_0-auc:0.88859
# [357]	validation_0-auc:0.88865
# [358]	validation_0-auc:0.88861
# [359]	validation_0-auc:0.88868
# [360]	validation_0-auc:0.88863
# [361]	validation_0-auc:0.88862
# [362]	validation_0-auc:0.88856
# [363]	validation_0-auc:0.88858
# [364]	validation_0-auc:0.88851
# [365]	validation_0-auc:0.88851
# [366]	validation_0-auc:0.88854
# [367]	validation_0-auc:0.88864
# [368]	validation_0-auc:0.88871
# [369]	validation_0-auc:0.88876
# [370]	validation_0-auc:0.88879
# [371]	validation_0-auc:0.88883
# [372]	validation_0-auc:0.88885
# [373]	validation_0-auc:0.88884
# [374]	validation_0-auc:0.88881
# [375]	validation_0-auc:0.88879
# [376]	validation_0-auc:0.88882
# [377]	validation_0-auc:0.88883
# [378]	validation_0-auc:0.88877
# [379]	validation_0-auc:0.88879
# [380]	validation_0-auc:0.88884
# [381]	validation_0-auc:0.88892
# [382]	validation_0-auc:0.88888
# [383]	validation_0-auc:0.88887
# [384]	validation_0-auc:0.88883
# [385]	validation_0-auc:0.88892
# [386]	validation_0-auc:0.88905
# [387]	validation_0-auc:0.88905
# [388]	validation_0-auc:0.88904
# [389]	validation_0-auc:0.88911
# [390]	validation_0-auc:0.88911
# [391]	validation_0-auc:0.88915
# [392]	validation_0-auc:0.88917
# [393]	validation_0-auc:0.88922
# [394]	validation_0-auc:0.88928
# [395]	validation_0-auc:0.88937
# [396]	validation_0-auc:0.88933
# [397]	validation_0-auc:0.88934
# [398]	validation_0-auc:0.88942
# [399]	validation_0-auc:0.88946
# [400]	validation_0-auc:0.88947
# [401]	validation_0-auc:0.88950
# [402]	validation_0-auc:0.88954
# [403]	validation_0-auc:0.88950
# [404]	validation_0-auc:0.88958
# [405]	validation_0-auc:0.88957
# [406]	validation_0-auc:0.88957
# [407]	validation_0-auc:0.88962
# [408]	validation_0-auc:0.88966
# [409]	validation_0-auc:0.88967
# [410]	validation_0-auc:0.88972
# [411]	validation_0-auc:0.88970
# [412]	validation_0-auc:0.88974
# [413]	validation_0-auc:0.88976
# [414]	validation_0-auc:0.88978
# [415]	validation_0-auc:0.88978
# [416]	validation_0-auc:0.88983
# [417]	validation_0-auc:0.88986
# [418]	validation_0-auc:0.88988
# [419]	validation_0-auc:0.88990
# [420]	validation_0-auc:0.88990
# [421]	validation_0-auc:0.88989
# [422]	validation_0-auc:0.88989
# [423]	validation_0-auc:0.88996
# [424]	validation_0-auc:0.88998
# [425]	validation_0-auc:0.88998
# [426]	validation_0-auc:0.88999
# [427]	validation_0-auc:0.88992
# [428]	validation_0-auc:0.88991
# [429]	validation_0-auc:0.88994
# [430]	validation_0-auc:0.88988
# [431]	validation_0-auc:0.88986
# [432]	validation_0-auc:0.88985
# [433]	validation_0-auc:0.88986
# [434]	validation_0-auc:0.88988
# [435]	validation_0-auc:0.88994
# ### performance metrics for the model
# # auc_train: 0.966
# # auc_test: 0.890

# %% [markdown]
# # Part 3 of 3: Perform hyperparameter tuning; try model with best parameters

# %%
#-- hyperparameter tuning using GridSearchCV

list_learning_rates = [0.02, 0.05, 0.1]
list_max_depth = [2, 3, 5]
list_n_estimators = [1000, 2000, 3000]

param_grid = {
    'learning_rate': list_learning_rates,
    'max_depth': list_max_depth,
    'n_estimators': list_n_estimators
}

#-- make a function to be used for scoring

def my_roc_auc_score(model, X, y):
  return roc_auc_score(y, model.predict_proba(X)[:, 1])

model_xgboost_hp = GridSearchCV(estimator=xgboost.XGBClassifier(subsample=0.5,
                                                               colsample_bytree=0.25,
                                                               eval_metric='auc',
                                                               use_label_encoder=False),
                               param_grid=param_grid,
                               cv=2,
                               scoring=my_roc_auc_score,
                               return_train_score=True,
                               verbose=4)

model_xgboost_hp.fit(X, y)

df_cv_results = pd.DataFrame(model_xgboost_hp.cv_results_)
df_cv_results = df_cv_results[['rank_test_score', 'mean_test_score', 'mean_train_score',
                               'param_learning_rate','param_max_depth', 'param_n_estimators']]

df_cv_results.sort_values(by='rank_test_score', inplace=True)

print('### View top 5 results after using GridSearchCV')
print(df_cv_results.head())
# Out:
# Fitting 2 folds for each of 27 candidates, totalling 54 fits
# [CV 1/2] END learning_rate=0.02, max_depth=2, n_estimators=1000;, score=(train=0.879, test=0.855) total time=  56.9s
# [CV 2/2] END learning_rate=0.02, max_depth=2, n_estimators=1000;, score=(train=0.876, test=0.861) total time=  57.2s
# [CV 1/2] END learning_rate=0.02, max_depth=2, n_estimators=2000;, score=(train=0.905, test=0.877) total time= 1.9min
# [CV 2/2] END learning_rate=0.02, max_depth=2, n_estimators=2000;, score=(train=0.901, test=0.883) total time= 1.9min
# [CV 1/2] END learning_rate=0.02, max_depth=2, n_estimators=3000;, score=(train=0.917, test=0.886) total time= 2.8min
# [CV 2/2] END learning_rate=0.02, max_depth=2, n_estimators=3000;, score=(train=0.913, test=0.892) total time= 2.8min
# [CV 1/2] END learning_rate=0.02, max_depth=3, n_estimators=1000;, score=(train=0.907, test=0.869) total time= 1.1min
# [CV 2/2] END learning_rate=0.02, max_depth=3, n_estimators=1000;, score=(train=0.903, test=0.875) total time= 1.1min
# [CV 1/2] END learning_rate=0.02, max_depth=3, n_estimators=2000;, score=(train=0.931, test=0.886) total time= 2.2min
# [CV 2/2] END learning_rate=0.02, max_depth=3, n_estimators=2000;, score=(train=0.928, test=0.891) total time= 2.2min
# [CV 1/2] END learning_rate=0.02, max_depth=3, n_estimators=3000;, score=(train=0.943, test=0.892) total time= 3.4min
# [CV 2/2] END learning_rate=0.02, max_depth=3, n_estimators=3000;, score=(train=0.940, test=0.897) total time= 3.4min
# [CV 1/2] END learning_rate=0.02, max_depth=5, n_estimators=1000;, score=(train=0.960, test=0.882) total time= 1.8min
# [CV 2/2] END learning_rate=0.02, max_depth=5, n_estimators=1000;, score=(train=0.957, test=0.888) total time= 1.6min
# [CV 1/2] END learning_rate=0.02, max_depth=5, n_estimators=2000;, score=(train=0.982, test=0.891) total time= 3.2min
# [CV 2/2] END learning_rate=0.02, max_depth=5, n_estimators=2000;, score=(train=0.981, test=0.895) total time= 3.2min
# [CV 1/2] END learning_rate=0.02, max_depth=5, n_estimators=3000;, score=(train=0.992, test=0.892) total time= 4.8min
# [CV 2/2] END learning_rate=0.02, max_depth=5, n_estimators=3000;, score=(train=0.991, test=0.897) total time= 4.7min
# [CV 1/2] END learning_rate=0.05, max_depth=2, n_estimators=1000;, score=(train=0.910, test=0.881) total time=  59.8s
# [CV 2/2] END learning_rate=0.05, max_depth=2, n_estimators=1000;, score=(train=0.906, test=0.886) total time=  58.9s
# [CV 1/2] END learning_rate=0.05, max_depth=2, n_estimators=2000;, score=(train=0.927, test=0.892) total time= 1.9min
# [CV 2/2] END learning_rate=0.05, max_depth=2, n_estimators=2000;, score=(train=0.924, test=0.897) total time= 1.9min
# [CV 1/2] END learning_rate=0.05, max_depth=2, n_estimators=3000;, score=(train=0.935, test=0.894) total time= 3.0min
# [CV 2/2] END learning_rate=0.05, max_depth=2, n_estimators=3000;, score=(train=0.932, test=0.898) total time= 3.0min
# [CV 1/2] END learning_rate=0.05, max_depth=3, n_estimators=1000;, score=(train=0.936, test=0.887) total time= 1.2min
# [CV 2/2] END learning_rate=0.05, max_depth=3, n_estimators=1000;, score=(train=0.932, test=0.893) total time= 1.2min
# [CV 1/2] END learning_rate=0.05, max_depth=3, n_estimators=2000;, score=(train=0.955, test=0.892) total time= 2.4min
# [CV 2/2] END learning_rate=0.05, max_depth=3, n_estimators=2000;, score=(train=0.953, test=0.896) total time= 2.4min
# [CV 1/2] END learning_rate=0.05, max_depth=3, n_estimators=3000;, score=(train=0.968, test=0.892) total time= 3.6min
# [CV 2/2] END learning_rate=0.05, max_depth=3, n_estimators=3000;, score=(train=0.967, test=0.896) total time= 3.5min
# [CV 1/2] END learning_rate=0.05, max_depth=5, n_estimators=1000;, score=(train=0.986, test=0.887) total time= 1.8min
# [CV 2/2] END learning_rate=0.05, max_depth=5, n_estimators=1000;, score=(train=0.985, test=0.892) total time= 1.8min
# [CV 1/2] END learning_rate=0.05, max_depth=5, n_estimators=2000;, score=(train=0.999, test=0.886) total time= 3.4min
# [CV 2/2] END learning_rate=0.05, max_depth=5, n_estimators=2000;, score=(train=0.999, test=0.891) total time= 3.3min
# [CV 1/2] END learning_rate=0.05, max_depth=5, n_estimators=3000;, score=(train=1.000, test=0.885) total time= 5.1min
# [CV 2/2] END learning_rate=0.05, max_depth=5, n_estimators=3000;, score=(train=1.000, test=0.890) total time= 5.0min
# [CV 1/2] END learning_rate=0.1, max_depth=2, n_estimators=1000;, score=(train=0.925, test=0.890) total time= 1.0min
# [CV 2/2] END learning_rate=0.1, max_depth=2, n_estimators=1000;, score=(train=0.922, test=0.895) total time=  59.9s
# [CV 1/2] END learning_rate=0.1, max_depth=2, n_estimators=2000;, score=(train=0.940, test=0.892) total time= 2.0min
# [CV 2/2] END learning_rate=0.1, max_depth=2, n_estimators=2000;, score=(train=0.937, test=0.896) total time= 1.9min
# [CV 1/2] END learning_rate=0.1, max_depth=2, n_estimators=3000;, score=(train=0.952, test=0.891) total time= 3.0min
# [CV 2/2] END learning_rate=0.1, max_depth=2, n_estimators=3000;, score=(train=0.949, test=0.894) total time= 3.0min
# [CV 1/2] END learning_rate=0.1, max_depth=3, n_estimators=1000;, score=(train=0.952, test=0.889) total time= 1.2min
# [CV 2/2] END learning_rate=0.1, max_depth=3, n_estimators=1000;, score=(train=0.950, test=0.893) total time= 1.2min
# [CV 1/2] END learning_rate=0.1, max_depth=3, n_estimators=2000;, score=(train=0.977, test=0.886) total time= 2.4min
# [CV 2/2] END learning_rate=0.1, max_depth=3, n_estimators=2000;, score=(train=0.976, test=0.890) total time= 2.4min
# [CV 1/2] END learning_rate=0.1, max_depth=3, n_estimators=3000;, score=(train=0.991, test=0.884) total time= 3.6min
# [CV 2/2] END learning_rate=0.1, max_depth=3, n_estimators=3000;, score=(train=0.990, test=0.887) total time= 3.6min
# [CV 1/2] END learning_rate=0.1, max_depth=5, n_estimators=1000;, score=(train=0.998, test=0.879) total time= 1.8min
# [CV 2/2] END learning_rate=0.1, max_depth=5, n_estimators=1000;, score=(train=0.998, test=0.884) total time= 1.8min
# [CV 1/2] END learning_rate=0.1, max_depth=5, n_estimators=2000;, score=(train=1.000, test=0.877) total time= 3.5min
# [CV 2/2] END learning_rate=0.1, max_depth=5, n_estimators=2000;, score=(train=1.000, test=0.883) total time= 3.5min
# [CV 1/2] END learning_rate=0.1, max_depth=5, n_estimators=3000;, score=(train=1.000, test=0.879) total time= 5.2min
# [CV 2/2] END learning_rate=0.1, max_depth=5, n_estimators=3000;, score=(train=1.000, test=0.884) total time= 5.2min
# ### View top 5 results after using GridSearchCV
#     rank_test_score  mean_test_score  mean_train_score param_learning_rate  \
# 11                1         0.896244          0.933404                0.05
# 13                2         0.894368          0.953949                0.05
# 10                3         0.894299          0.925198                0.05
# 5                 4         0.894226          0.941276                0.02
# 8                 5         0.894182          0.991554                0.02
#
#    param_max_depth param_n_estimators
# 11               2               3000
# 13               3               2000
# 10               2               2000
# 5                3               3000
# 8                5               3000

# %%
#-- try the best model

best_learning_rate = df_cv_results['learning_rate'].iloc[0]
best_max_depth = df_cv_results['max_depth'].iloc[0]
best_n_estimators = df_cv_results['n_estimators'].iloc[0]

model_xgboost = xgboost.XGBClassifier(learning_rate=best_learning_rate,
                                      max_depth=best_max_depth,
                                      n_estimators=best_n_estimators,
                                      subsample=0.5,
                                      colsample_bytree=0.25,
                                      eval_metric='auc',
                                      verbosity=1)

model_xgboost.fit(X_train,
                  y_train,
                  early_stopping_rounds=10,
                  eval_set=test_set,
                  verbose=False)

y_preds_train = model_xgboost.predict_proba(X_train)[:, 1]
y_preds_test = model_xgboost.predict_proba(X_test)[:, 1]

y_preds_binary_test = model_xgboost.predict(X_test)
model_class_report = classification_report(y_test, y_preds_binary_test)

auc_train = roc_auc_score(y_train, y_preds_train)
auc_test = roc_auc_score(y_test, y_preds_test)

print('### performance metrics for the model')
print(f'# auc_train: {auc_train:.3f}')
print(f'# auc_test: {auc_test:.3f}')
print('# classification report:')
print(model_class_report)
# Out:
# ### performance metrics for the model
# # auc_train: 0.915
# # auc_test: 0.897
# # classification report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96     35936
#            1       0.83      0.28      0.42      4064
#
#     accuracy                           0.92     40000
#    macro avg       0.88      0.64      0.69     40000
# weighted avg       0.91      0.92      0.90     40000
